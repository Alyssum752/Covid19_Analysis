# %% [markdown]
# ## Categorizing US counties

# %%
import pandas as pd

# %% [markdown]
# ### Import county category data
# Source: NCHS Urban-Rural Classification Scheme for Counties
#
# ##### The NCHS has developed a six-level urban-rural classification scheme for U.S. counties and county-equivalent entities.
# 1. Metropolitan counties: Large central metro counties in MSA of 1 million population that: 1) contain the entire population of the largest principal city of the MSA, or 2) are completely contained within the largest principal city of the MSA, or 3) contain at least 250,000 residents of any principal city in the MSA.
# 2. Large fringe metro counties in MSA of 1 million or more population that do not qualify as large central
# 3. Medium metro counties in MSA of 250,000-999,999 population.
# 4. Small metro counties are counties in MSAs of less than 250,000 population.
# 5. Micropolitan counties in micropolitan statistical area
# 6. Noncore counties not in micropolitan statistical areas
#
# ##### We can farther collapse these six categories into urban, suburban, and rural:
# - Urban: 1 (Large central metro)
# - Suburban: 2, 3, 4 (Large fringe metro counties, medium metro, and small metro counties)
# - Rural: 5 and 6 (Micropolitan counties and Noncore counties)

# %%
county_categories = pd.read_excel("NCHSURCodes2013.xlsx")
print(county_categories.shape)
county_categories.head()
# Out:
# (3149, 9)
#    FIPS code State Abr.     County name                 CBSA title  \
# 0       1001         AL  Autauga County             Montgomery, AL
# 1       1003         AL  Baldwin County  Daphne-Fairhope-Foley, AL
# 2       1005         AL  Barbour County                        NaN
# 3       1007         AL     Bibb County      Birmingham-Hoover, AL
# 4       1009         AL   Blount County      Birmingham-Hoover, AL
#
#   CBSA 2012 pop County 2012 pop  2013 code  2006 code 1990-based code
# 0        377149           55514          3          3               3
# 1        190790          190790          4          5               3
# 2             .           27201          6          5               5
# 3       1136650           22597          2          2               6
# 4       1136650           57826          2          2               3

# %%
selected = county_categories[["FIPS code", "2013 code"]]
selected.astype({"FIPS code": "int64"})
selected.head()
# Out:
#    FIPS code  2013 code
# 0       1001          3
# 1       1003          4
# 2       1005          6
# 3       1007          2
# 4       1009          2

# %% [markdown]
# ### Import County-level Covid Data
# Source: NY Times (https://github.com/nytimes/covid-19-data)

# %%
url = "https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv"

covid_by_counties = pd.read_csv(url, error_bad_lines=False)

print(covid_by_counties.shape)
covid_by_counties.head()
# Out:
# (1215836, 6)
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0

# %% [markdown]
# ### Merging and Fixing
#
# The first merge attempt shows that three of the counties in this dataset do not come with fips county code that identifies them. They are New York City, Kansas City, and Joplin.
#
# We will fill in the fips code for New York City with that of New York County because they generally refer to the same region.
#
# Joplin (Missouri) is a city in both Jasper and Newton County. Since both are designated by the NCHS system as small metro counties and Joplin is mostly in Jasper County, we will fill in the Joplin FIPS code with the Jasper County FIPS code.
#
# Kansas City (Missouri) straddles the Kansas-Missouri state line. The bulk of it is in Jackson County, Missouri, but parts of it lie in Clay, Cass, and Platte Counties. We will fill in the Kansas City FIPS with that of Jackson County.

# %%
with_categories_left_1 = pd.merge(covid_by_counties, selected, left_on = "fips", right_on = "FIPS code", how = "left")
print(with_categories_left_1.shape)
with_categories_left_1[with_categories_left_1["fips"].isnull()].groupby("county").sum()
# Out:
# (1215836, 8)
#                fips      cases     deaths  FIPS code  2013 code
# county
# Joplin          0.0     834163    15601.0        0.0        0.0
# Kansas City     0.0    6412753    80624.0        0.0        0.0
# New York City   0.0  135733939  8891474.0        0.0        0.0
# Unknown         0.0   14711692   620972.0        0.0        0.0

# %%
covid_by_counties.loc[covid_by_counties["county"] == "New York City", "fips"] = 36061
covid_by_counties.loc[covid_by_counties["county"] == "Joplin", "fips"] = 29097
covid_by_counties.loc[covid_by_counties["county"] == "Kansas City", "fips"] = 29095

# %%
with_categories_left_2 = pd.merge(covid_by_counties, selected, left_on = "fips", right_on = "FIPS code", how = "left")
print(with_categories_left_2.shape)
with_categories_left_2[with_categories_left_2["fips"].isnull()].groupby("county").sum()
# Out:
# (1215836, 8)
#          fips     cases    deaths  FIPS code  2013 code
# county
# Unknown   0.0  14711692  620972.0        0.0        0.0

# %%
print(with_categories_left_2[with_categories_left_2["fips"].isnull()].shape[0])
print(with_categories_left_2[with_categories_left_2["fips"].isnull()].shape[0]/with_categories_left_2.shape[0])
print(with_categories_left_2[with_categories_left_2["fips"].isnull()].groupby("state").sum().shape)
print(with_categories_left_2[with_categories_left_2["fips"].isnull() == False].groupby("state").sum().shape)
# Out:
# 10040
# 0.008257692649337576
# (53, 5)
# (54, 5)

# %% [markdown]
# After fixing the fips codes above, we are only missing county information on 9257 entries in the 1118423-entry dataset. That is only 0.83% of the data. We also check to make sure all 50 states are represented in our dataset.

# %% [markdown]
# ### Dividing into Urban, Suburban, and Rural

# %%
with_categories_left_2.loc[with_categories_left_2["2013 code"] == 1, "category"] = "Urban"
with_categories_left_2.loc[with_categories_left_2["2013 code"] == 2, "category"] = "Suburban"
with_categories_left_2.loc[with_categories_left_2["2013 code"] == 3, "category"] = "Suburban"
with_categories_left_2.loc[with_categories_left_2["2013 code"] == 4, "category"] = "Suburban"
with_categories_left_2.loc[with_categories_left_2["2013 code"] == 5, "category"] = "Rural"
with_categories_left_2.loc[with_categories_left_2["2013 code"] == 6, "category"] = "Rural"

# %%
with_categories_left_2.head()
# Out:
#          date     county       state     fips  cases  deaths  FIPS code  \
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0    53061.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0    53061.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0    53061.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0    17031.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0    53061.0
#
#    2013 code  category
# 0        2.0  Suburban
# 1        2.0  Suburban
# 2        2.0  Suburban
# 3        1.0     Urban
# 4        2.0  Suburban

# %% [markdown]
# ### Import College Data

# %%
college_url = "https://raw.githubusercontent.com/nytimes/covid-19-data/master/colleges/colleges.csv"

covid_by_college = pd.read_csv(college_url, error_bad_lines=False)

print(covid_by_college.shape)
covid_by_college.head()
# Out:
# (1949, 9)
#          date    state      county        city ipeds_id  \
# 0  2021-02-26  Alabama     Madison  Huntsville   100654
# 1  2021-02-26  Alabama  Montgomery  Montgomery   100724
# 2  2021-02-26  Alabama   Limestone      Athens   100812
# 3  2021-02-26  Alabama         Lee      Auburn   100858
# 4  2021-02-26  Alabama  Montgomery  Montgomery   100830
#
#                            college  cases  cases_2021 notes
# 0           Alabama A&M University     41         NaN   NaN
# 1         Alabama State University      2         NaN   NaN
# 2          Athens State University     45        10.0   NaN
# 3                Auburn University   2499       324.0   NaN
# 4  Auburn University at Montgomery    214        74.0   NaN

# %% [markdown]
# ### Import total county cases data

# %%
county_total_url = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-counties.csv'
covid_by_county_total = pd.read_csv(county_total_url, error_bad_lines=False)
print(covid_by_county_total.shape)
covid_by_county_total.head()
# Out:
# (3247, 10)
#          date   county    state    fips  cases  deaths  confirmed_cases  \
# 0  2021-04-13  Autauga  Alabama  1001.0   6727   103.0           5741.0
# 1  2021-04-13  Baldwin  Alabama  1003.0  20638   300.0          14608.0
# 2  2021-04-13  Barbour  Alabama  1005.0   2249    55.0           1256.0
# 3  2021-04-13     Bibb  Alabama  1007.0   2564    58.0           2073.0
# 4  2021-04-13   Blount  Alabama  1009.0   6488   135.0           4997.0
#
#    confirmed_deaths  probable_cases  probable_deaths
# 0              90.0           986.0             13.0
# 1             224.0          6030.0             76.0
# 2              36.0           993.0             19.0
# 3              35.0           491.0             23.0
# 4             113.0          1491.0             22.0

# %% [markdown]
# ### Merging and Fixing College Data with County Data

# %%
college_merge_with_county = covid_by_county_total.merge(covid_by_college, on = ['county','state'], how = 'outer')
college_merge_with_county = college_merge_with_county.merge(county_categories, left_on = 'fips', right_on = 'FIPS code')
college_merge_with_county = college_merge_with_county.drop(columns = ['CBSA title', '1990-based code', '2006 code', 'County name','State Abr.','FIPS code','cases_2021','notes','CBSA 2012 pop', 'date_y', 'city'])
college_merge_with_county = college_merge_with_county.rename({'cases_x': 'county_cases', 'cases_y': 'college_cases', 'date_x':'Date'}, axis=1)
college_merge_with_county['infection_rate'] = college_merge_with_county['county_cases']/college_merge_with_county['County 2012 pop']
print(college_merge_with_county.shape)

college_merge_with_county.head(50)
# Out:
# (4012, 16)
#           Date      county    state    fips  county_cases  deaths  \
# 0   2021-04-13     Autauga  Alabama  1001.0        6727.0   103.0
# 1   2021-04-13     Baldwin  Alabama  1003.0       20638.0   300.0
# 2   2021-04-13     Barbour  Alabama  1005.0        2249.0    55.0
# 3   2021-04-13        Bibb  Alabama  1007.0        2564.0    58.0
# 4   2021-04-13      Blount  Alabama  1009.0        6488.0   135.0
# 5   2021-04-13     Bullock  Alabama  1011.0        1213.0    40.0
# 6   2021-04-13      Butler  Alabama  1013.0        2123.0    66.0
# 7   2021-04-13     Calhoun  Alabama  1015.0       14286.0   311.0
# 8   2021-04-13    Chambers  Alabama  1017.0        3500.0   122.0
# 9   2021-04-13    Cherokee  Alabama  1019.0        1820.0    44.0
# 10  2021-04-13     Chilton  Alabama  1021.0        4083.0   109.0
# 11  2021-04-13     Choctaw  Alabama  1023.0         587.0    24.0
# 12  2021-04-13      Clarke  Alabama  1025.0        3463.0    60.0
# 13  2021-04-13        Clay  Alabama  1027.0        1494.0    54.0
# 14  2021-04-13    Cleburne  Alabama  1029.0        1460.0    41.0
# 15  2021-04-13      Coffee  Alabama  1031.0        5401.0   112.0
# 16  2021-04-13     Colbert  Alabama  1033.0        6205.0   130.0
# 17  2021-04-13     Conecuh  Alabama  1035.0        1090.0    28.0
# 18  2021-04-13       Coosa  Alabama  1037.0         993.0    28.0
# 19  2021-04-13   Covington  Alabama  1039.0        4053.0   114.0
# 20  2021-04-13    Crenshaw  Alabama  1041.0        1493.0    57.0
# 21  2021-04-13     Cullman  Alabama  1043.0        9475.0   188.0
# 22  2021-04-13        Dale  Alabama  1045.0        4768.0   110.0
# 23  2021-04-13      Dallas  Alabama  1047.0        3527.0   149.0
# 24  2021-04-13      DeKalb  Alabama  1049.0        8747.0   181.0
# 25  2021-04-13      Elmore  Alabama  1051.0        9994.0   200.0
# 26  2021-04-13    Escambia  Alabama  1053.0        3880.0    74.0
# 27  2021-04-13      Etowah  Alabama  1055.0       13664.0   345.0
# 28  2021-04-13     Fayette  Alabama  1057.0        2089.0    60.0
# 29  2021-04-13    Franklin  Alabama  1059.0        4199.0    82.0
# 30  2021-04-13      Geneva  Alabama  1061.0        2458.0    75.0
# 31  2021-04-13      Greene  Alabama  1063.0         907.0    34.0
# 32  2021-04-13        Hale  Alabama  1065.0        2187.0    75.0
# 33  2021-04-13       Henry  Alabama  1067.0        1878.0    44.0
# 34  2021-04-13     Houston  Alabama  1069.0       10383.0   278.0
# 35  2021-04-13     Jackson  Alabama  1071.0        6755.0   110.0
# 36  2021-04-13   Jefferson  Alabama  1073.0       75413.0  1487.0
# 37  2021-04-13   Jefferson  Alabama  1073.0       75413.0  1487.0
# 38  2021-04-13   Jefferson  Alabama  1073.0       75413.0  1487.0
# 39  2021-04-13   Jefferson  Alabama  1073.0       75413.0  1487.0
# 40  2021-04-13       Lamar  Alabama  1075.0        1393.0    34.0
# 41  2021-04-13  Lauderdale  Alabama  1077.0        9218.0   227.0
# 42  2021-04-13    Lawrence  Alabama  1079.0        2953.0    95.0
# 43  2021-04-13         Lee  Alabama  1081.0       15524.0   165.0
# 44  2021-04-13   Limestone  Alabama  1083.0        9814.0   147.0
# 45  2021-04-13   Limestone  Alabama  1083.0        9814.0   147.0
# 46  2021-04-13     Lowndes  Alabama  1085.0        1364.0    53.0
# 47  2021-04-13       Macon  Alabama  1087.0        1548.0    48.0
# 48  2021-04-13     Madison  Alabama  1089.0       33868.0   494.0
# 49  2021-04-13     Madison  Alabama  1089.0       33868.0   494.0
#
#     confirmed_cases  confirmed_deaths  probable_cases  probable_deaths  \
# 0            5741.0              90.0           986.0             13.0
# 1           14608.0             224.0          6030.0             76.0
# 2            1256.0              36.0           993.0             19.0
# 3            2073.0              35.0           491.0             23.0
# 4            4997.0             113.0          1491.0             22.0
# 5            1072.0              30.0           141.0             10.0
# 6            1928.0              59.0           195.0              7.0
# 7           10691.0             251.0          3595.0             60.0
# 8            1740.0              77.0          1760.0             45.0
# 9            1166.0              33.0           654.0             11.0
# 10           3346.0              83.0           737.0             26.0
# 11            499.0              13.0            88.0             11.0
# 12           2473.0              44.0           990.0             16.0
# 13           1181.0              48.0           313.0              6.0
# 14           1295.0              33.0           165.0              8.0
# 15           3546.0              47.0          1855.0             65.0
# 16           4427.0             110.0          1778.0             20.0
# 17            830.0              25.0           260.0              3.0
# 18            580.0              25.0           413.0              3.0
# 19           1990.0              76.0          2063.0             38.0
# 20           1096.0              49.0           397.0              8.0
# 21           6432.0             126.0          3043.0             62.0
# 22           3166.0              87.0          1602.0             23.0
# 23           2652.0             112.0           875.0             37.0
# 24           7495.0             151.0          1252.0             30.0
# 25           7356.0             162.0          2638.0             38.0
# 26           2300.0              56.0          1580.0             18.0
# 27          10839.0             283.0          2825.0             62.0
# 28           1694.0              44.0           395.0             16.0
# 29           3404.0              68.0           795.0             14.0
# 30           1540.0              36.0           918.0             39.0
# 31            762.0              26.0           145.0              8.0
# 32           1675.0              63.0           512.0             12.0
# 33           1078.0              26.0           800.0             18.0
# 34           5623.0             169.0          4760.0            109.0
# 35           5609.0              83.0          1146.0             27.0
# 36          67235.0            1203.0          8178.0            284.0
# 37          67235.0            1203.0          8178.0            284.0
# 38          67235.0            1203.0          8178.0            284.0
# 39          67235.0            1203.0          8178.0            284.0
# 40           1113.0              25.0           280.0              9.0
# 41           5835.0             181.0          3383.0             46.0
# 42           2386.0              81.0           567.0             14.0
# 43           8674.0             101.0          6850.0             64.0
# 44           8275.0             122.0          1539.0             25.0
# 45           8275.0             122.0          1539.0             25.0
# 46           1258.0              48.0           106.0              5.0
# 47           1220.0              37.0           328.0             11.0
# 48          29331.0             384.0          4537.0            110.0
# 49          29331.0             384.0          4537.0            110.0
#
#     ipeds_id                               college  college_cases  \
# 0        NaN                                   NaN            NaN
# 1        NaN                                   NaN            NaN
# 2        NaN                                   NaN            NaN
# 3        NaN                                   NaN            NaN
# 4        NaN                                   NaN            NaN
# 5        NaN                                   NaN            NaN
# 6        NaN                                   NaN            NaN
# 7     101480         Jacksonville State University          229.0
# 8        NaN                                   NaN            NaN
# 9        NaN                                   NaN            NaN
# 10       NaN                                   NaN            NaN
# 11       NaN                                   NaN            NaN
# 12       NaN                                   NaN            NaN
# 13       NaN                                   NaN            NaN
# 14       NaN                                   NaN            NaN
# 15    101143    Enterprise State Community College           59.0
# 16       NaN                                   NaN            NaN
# 17       NaN                                   NaN            NaN
# 18       NaN                                   NaN            NaN
# 19    101602  Lurleen B. Wallace Community College           19.0
# 20       NaN                                   NaN            NaN
# 21       NaN                                   NaN            NaN
# 22       NaN                                   NaN            NaN
# 23       NaN                                   NaN            NaN
# 24       NaN                                   NaN            NaN
# 25       NaN                                   NaN            NaN
# 26       NaN                                   NaN            NaN
# 27    101240       Gadsden State Community College           67.0
# 28       NaN                                   NaN            NaN
# 29       NaN                                   NaN            NaN
# 30       NaN                                   NaN            NaN
# 31       NaN                                   NaN            NaN
# 32       NaN                                   NaN            NaN
# 33       NaN                                   NaN            NaN
# 34  10236803                Troy University Dothan           18.0
# 35       NaN                                   NaN            NaN
# 36    100937           Birmingham-Southern College          252.0
# 37    101675                         Miles College            0.0
# 38    102049                    Samford University          596.0
# 39    100663   University of Alabama at Birmingham         2856.0
# 40       NaN                                   NaN            NaN
# 41    101879           University of North Alabama          683.0
# 42       NaN                                   NaN            NaN
# 43    100858                     Auburn University         2499.0
# 44    100812               Athens State University           45.0
# 45    101514             Calhoun Community College          128.0
# 46       NaN                                   NaN            NaN
# 47    102377                   Tuskegee University          110.0
# 48    100654                Alabama A&M University           41.0
# 49    100706   University of Alabama in Huntsville          331.0
#
#    County 2012 pop  2013 code infection_rate
# 0            55514          3       0.121177
# 1           190790          4       0.108171
# 2            27201          6      0.0826808
# 3            22597          2       0.113466
# 4            57826          2       0.112199
# 5            10474          6       0.115811
# 6            20307          6       0.104545
# 7           117296          4       0.121794
# 8            34064          5       0.102748
# 9            26021          6      0.0699435
# 10           43819          2      0.0931788
# 11           13633          6      0.0430573
# 12           25161          6       0.137634
# 13           13435          6       0.111202
# 14           14832          6      0.0984358
# 15           51252          5       0.105381
# 16           54446          4       0.113966
# 17           12981          6      0.0839689
# 18           10966          5      0.0905526
# 19           37955          6       0.106784
# 20           14083          6       0.106014
# 21           80440          5        0.11779
# 22           50444          5      0.0945207
# 23           42864          5      0.0822835
# 24           71080          6       0.123059
# 25           80629          3        0.12395
# 26           37994          6       0.102121
# 27          104392          4       0.130891
# 28           16983          6       0.123005
# 29           31761          6       0.132206
# 30           26931          4      0.0912703
# 31            8876          6       0.102186
# 32           15388          4       0.142124
# 33           17287          4       0.108637
# 34          103402          4       0.100414
# 35           53019          5       0.127407
# 36          660009          1       0.114261
# 37          660009          1       0.114261
# 38          660009          1       0.114261
# 39          660009          1       0.114261
# 40           14259          6      0.0976927
# 41           92542          4      0.0996088
# 42           33838          4      0.0872688
# 43          147257          4       0.105421
# 44           87654          3       0.111963
# 45           87654          3       0.111963
# 46           10857          3       0.125633
# 47           20535          6      0.0753835
# 48          343080          3      0.0987175
# 49          343080          3      0.0987175

# %% [markdown]
# ### Import Mobility Data

# %%
mobility_data = pd.read_csv('Apple-Mobility-Data.csv', dtype={'alternative_name': 'string'})
# Drop dates before COVID lockdowns
lst = []
for i in range(13, 32):
    lst.append("2020-01-" + str(i))
for i in range(1, 10):
    lst.append("2020-02-0" + str(i))
for i in range(10, 30):
    lst.append("2020-02-" + str(i))
for i in range(1, 10):
    lst.append("2020-03-0" + str(i))
for i in range(10, 13):
    lst.append("2020-03-" + str(i))
mobility_data = mobility_data.drop(columns=lst, axis=1)
mobility_data.head()
# Out:
#          geo_type     region transportation_type alternative_name sub-region  \
# 0  country/region    Albania             driving             <NA>        NaN
# 1  country/region    Albania             walking             <NA>        NaN
# 2  country/region  Argentina             driving             <NA>        NaN
# 3  country/region  Argentina             walking             <NA>        NaN
# 4  country/region  Australia             driving               AU        NaN
#
#   country  2020-03-13  2020-03-14  2020-03-15  2020-03-16  ...  2021-03-20  \
# 0     NaN       24.99       24.61       30.93       24.69  ...      124.45
# 1     NaN       31.43       37.78       37.44       35.95  ...      133.05
# 2     NaN       98.75       84.77       47.70       53.57  ...      106.11
# 3     NaN      104.31       70.31       43.64       51.55  ...       80.48
# 4     NaN       98.75       78.16       81.59       80.52  ...       97.19
#
#    2021-03-21  2021-03-22  2021-03-23  2021-03-24  2021-03-25  2021-03-26  \
# 0      113.95       98.84      117.22      102.75      105.33      114.25
# 1      110.41      122.64      142.64      140.04      129.98      146.01
# 2       74.13       73.24       93.80       73.71       74.27      101.48
# 3       54.61       68.93       85.16       59.04       62.92       86.99
# 4      102.72      101.59      110.29      115.88      125.08      125.53
#
#    2021-03-27  2021-03-28  2021-03-29
# 0      142.29      150.08      115.24
# 1      158.98      143.58      146.31
# 2      108.56       66.71       72.20
# 3       83.76       47.22       65.93
# 4      103.02      106.90      103.76
#
# [5 rows x 388 columns]

# %% [markdown]
# #### Filtering data
# Here we filter out data from other countries and geo_types to get only US county data. We also filter that out further to separate data for driving, transit, and walking.

# %%
mobility_data = mobility_data[mobility_data['country'] == "United States"]
mobility_data = mobility_data[mobility_data['geo_type'] == "county"]
mobility_data = mobility_data.drop(columns=['alternative_name', 'country', 'geo_type'])
driving_data = mobility_data[mobility_data['transportation_type'] == "driving"]
transit_data = mobility_data[mobility_data['transportation_type'] == "transit"]
walking_data = mobility_data[mobility_data['transportation_type'] == "walking"]
driving_data.head()
# Out:
#                 region transportation_type      sub-region  2020-03-13  \
# 2053  Abbeville County             driving  South Carolina      146.21
# 2054     Acadia Parish             driving       Louisiana      175.85
# 2055   Accomack County             driving        Virginia      147.22
# 2056        Ada County             driving           Idaho      129.56
# 2058      Adair County             driving        Kentucky      112.85
#
#       2020-03-14  2020-03-15  2020-03-16  2020-03-17  2020-03-18  2020-03-19  \
# 2053      145.93       89.48      108.42      105.33      108.49      106.52
# 2054      161.18      127.97      167.33      107.82      109.49      107.61
# 2055      138.99      112.78      107.28       92.54       95.38       90.77
# 2056      110.05       68.63       94.29       88.89       86.43       88.61
# 2058      101.52       85.55       81.72       81.40       89.62       87.63
#
#       ...  2021-03-20  2021-03-21  2021-03-22  2021-03-23  2021-03-24  \
# 2053  ...      213.04      149.37      179.66      169.14      183.80
# 2054  ...      228.85      178.33      164.56      154.64      157.82
# 2055  ...      178.99      170.18      158.46      142.84      141.12
# 2056  ...      171.82      122.79      141.04      145.35      145.06
# 2058  ...      191.22      141.90      136.23      161.21      155.23
#
#       2021-03-25  2021-03-26  2021-03-27  2021-03-28  2021-03-29
# 2053      184.92      200.91      199.09      146.70      177.21
# 2054      177.03      209.16      199.36      146.89      164.88
# 2055      164.56      213.02      231.30      188.52      192.25
# 2056      148.28      169.82      159.18      119.54      140.01
# 2058      144.53      206.38      188.03      130.25      149.88
#
# [5 rows x 385 columns]

# %%
driving_data['average_mobility'] = driving_data.mean(axis=1, numeric_only=True)
driving_data = driving_data.filter(['region', 'sub-region', 'average_mobility'])
# Out:
# <ipython-input-32-a24a50f8268f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   driving_data['average_mobility'] = driving_data.mean(axis=1, numeric_only=True)

# %% [markdown]
# #### Merging driving data with counties + colleges

# %%
driving_data['region'] = driving_data['region'].map(lambda x: x.rstrip('County').rstrip())
college_county_with_driving = college_merge_with_county.merge(driving_data, left_on=['county', 'state'], right_on=['region', 'sub-region'], how='left')

# %%
combined_df = college_county_with_driving[college_county_with_driving['average_mobility'].notnull()]

# %%
#load college data 
colleges = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/colleges/colleges.csv')
colleges
# Out:
#             date      state      county          city ipeds_id  \
# 0     2021-02-26    Alabama     Madison    Huntsville   100654
# 1     2021-02-26    Alabama  Montgomery    Montgomery   100724
# 2     2021-02-26    Alabama   Limestone        Athens   100812
# 3     2021-02-26    Alabama         Lee        Auburn   100858
# 4     2021-02-26    Alabama  Montgomery    Montgomery   100830
# ...          ...        ...         ...           ...      ...
# 1944  2021-02-26  Wisconsin   Milwaukee     Milwaukee   240338
# 1945  2021-02-26    Wyoming     Natrona        Casper   240505
# 1946  2021-02-26    Wyoming      Goshen    Torrington   240596
# 1947  2021-02-26    Wyoming      Albany       Laramie   240727
# 1948  2021-02-26    Wyoming  Sweetwater  Rock Springs   240693
#
#                                 college  cases  cases_2021 notes
# 0                Alabama A&M University     41         NaN   NaN
# 1              Alabama State University      2         NaN   NaN
# 2               Athens State University     45        10.0   NaN
# 3                     Auburn University   2499       324.0   NaN
# 4       Auburn University at Montgomery    214        74.0   NaN
# ...                                 ...    ...         ...   ...
# 1944         Wisconsin Lutheran College    122         2.0   NaN
# 1945                     Casper College    363        33.0   NaN
# 1946            Eastern Wyoming College     13         1.0   NaN
# 1947              University of Wyoming   1970       175.0   NaN
# 1948  Western Wyoming Community College     85        20.0   NaN
#
# [1949 rows x 9 columns]

# %%
#clean college data
colleges = colleges.drop(columns = ['cases_2021', 'notes'])
colleges = colleges.drop_duplicates(subset=['state', 'county'])
colleges
# Out:
#             date      state      county          city ipeds_id  \
# 0     2021-02-26    Alabama     Madison    Huntsville   100654
# 1     2021-02-26    Alabama  Montgomery    Montgomery   100724
# 2     2021-02-26    Alabama   Limestone        Athens   100812
# 3     2021-02-26    Alabama         Lee        Auburn   100858
# 5     2021-02-26    Alabama      Walker        Jasper   102429
# ...          ...        ...         ...           ...      ...
# 1942  2021-02-26  Wisconsin    Walworth    Whitewater   240189
# 1945  2021-02-26    Wyoming     Natrona        Casper   240505
# 1946  2021-02-26    Wyoming      Goshen    Torrington   240596
# 1947  2021-02-26    Wyoming      Albany       Laramie   240727
# 1948  2021-02-26    Wyoming  Sweetwater  Rock Springs   240693
#
#                                  college  cases
# 0                 Alabama A&M University     41
# 1               Alabama State University      2
# 2                Athens State University     45
# 3                      Auburn University   2499
# 5         Bevill State Community College      4
# ...                                  ...    ...
# 1942  University of Wisconsin-Whitewater    779
# 1945                      Casper College    363
# 1946             Eastern Wyoming College     13
# 1947               University of Wyoming   1970
# 1948   Western Wyoming Community College     85
#
# [978 rows x 7 columns]

# %%
# Merge college data into mobility + county data
all_data = pd.merge(combined_df, colleges, on = ['county', 'state'], how = 'left')
all_data = all_data.drop(columns=['Date', 'fips', '2013 code', 'region', 'sub-region', 'date', 'city', 'ipeds_id_y', 'cases', 'ipeds_id_x', 'college_x'])
all_data = all_data.rename(columns={'college_y':'college'})

# %%
#separate into colleges and not colleges
counties_with_colleges = all_data[all_data['college'].notnull()]
counties_without_colleges = all_data[all_data['college'].isnull()]
counties_with_colleges.head()
# Out:
#        county    state  county_cases  deaths  confirmed_cases  \
# 6     Calhoun  Alabama       14286.0   311.0          10691.0
# 12     Coffee  Alabama        5401.0   112.0           3546.0
# 15  Covington  Alabama        4053.0   114.0           1990.0
# 22     Etowah  Alabama       13664.0   345.0          10839.0
# 26    Houston  Alabama       10383.0   278.0           5623.0
#
#     confirmed_deaths  probable_cases  probable_deaths  college_cases  \
# 6              251.0          3595.0             60.0          229.0
# 12              47.0          1855.0             65.0           59.0
# 15              76.0          2063.0             38.0           19.0
# 22             283.0          2825.0             62.0           67.0
# 26             169.0          4760.0            109.0           18.0
#
#    County 2012 pop infection_rate  average_mobility  \
# 6           117296       0.121794        128.573931
# 12           51252       0.105381        158.956253
# 15           37955       0.106784        191.223852
# 22          104392       0.130891        142.464406
# 26          103402       0.100414        147.749182
#
#                                  college
# 6          Jacksonville State University
# 12    Enterprise State Community College
# 15  Lurleen B. Wallace Community College
# 22       Gadsden State Community College
# 26                Troy University Dothan

# %%
counties_without_colleges.head()
# Out:
#     county    state  county_cases  deaths  confirmed_cases  confirmed_deaths  \
# 0  Autauga  Alabama        6727.0   103.0           5741.0              90.0
# 1  Baldwin  Alabama       20638.0   300.0          14608.0             224.0
# 2  Barbour  Alabama        2249.0    55.0           1256.0              36.0
# 3     Bibb  Alabama        2564.0    58.0           2073.0              35.0
# 4   Blount  Alabama        6488.0   135.0           4997.0             113.0
#
#    probable_cases  probable_deaths  college_cases County 2012 pop  \
# 0           986.0             13.0            NaN           55514
# 1          6030.0             76.0            NaN          190790
# 2           993.0             19.0            NaN           27201
# 3           491.0             23.0            NaN           22597
# 4          1491.0             22.0            NaN           57826
#
#   infection_rate  average_mobility college
# 0       0.121177        174.741794     NaN
# 1       0.108171        188.032005     NaN
# 2      0.0826808        203.113245     NaN
# 3       0.113466        167.044565     NaN
# 4       0.112199        140.813641     NaN

# %%
#take averages
counties_with_colleges_mob = counties_with_colleges['average_mobility'].mean()
print("With colleges mobility mean:", counties_with_colleges_mob)
counties_without_colleges_mob = counties_without_colleges['average_mobility'].mean()
print("Without colleges mobility mean:", counties_without_colleges_mob)
counties_with_colleges_mob = counties_with_colleges['average_mobility'].median()
print("With colleges mobility median:", counties_with_colleges_mob)
counties_without_colleges_mob = counties_without_colleges['average_mobility'].median()
print("Without colleges mobility median:", counties_without_colleges_mob)
# Out:
# With colleges mobility mean: 124.54028270761296
# Without colleges mobility mean: 152.4464317753483
# With colleges mobility median: 122.23976253298154
# Without colleges mobility median: 143.54362796833772

# %%
from scipy import stats
import numpy as np
#ttest_ind_from_stats

# %%
# Create testing means/std
with_colleges_cases_m = counties_with_colleges['infection_rate'].mean()
with_colleges_mob_m = counties_with_colleges['average_mobility'].mean()
with_colleges_cases_std = np.std(counties_with_colleges['infection_rate'])
with_colleges_mob_std = np.std(counties_with_colleges['average_mobility'])
without_colleges_cases_m = counties_without_colleges['infection_rate'].mean()
without_colleges_mob_m = counties_without_colleges['average_mobility'].mean()
without_colleges_cases_std = np.std(counties_without_colleges['infection_rate'])
without_colleges_mob_std = np.std(counties_without_colleges['average_mobility'])

# %%
# Hypothesis testing with colleges
stats.ttest_ind_from_stats(mean1=with_colleges_mob_m, std1=with_colleges_mob_std, nobs1=counties_with_colleges['infection_rate'].count(),
                                mean2=without_colleges_mob_m, std2=without_colleges_mob_std, nobs2=counties_without_colleges['infection_rate'].count())
# Out:
# Ttest_indResult(statistic=-22.61075481322922, pvalue=3.2801586488620443e-104)

# %% [markdown]
# ### Visualizations

# %%
import seaborn as sns

# %%
all_data['college_county'] = all_data['college'].notnull()

# %%
sns.relplot(x="average_mobility", y="infection_rate", hue="college_county", data=all_data)

# %%
sns.catplot(x="college_county", y="average_mobility", kind="box", data=all_data)

# %%
sns.displot(all_data, x="average_mobility", hue="college_county")
